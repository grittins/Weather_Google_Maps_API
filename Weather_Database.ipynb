# %%
# Import dependencies
import random
import numpy as np
from citipy import citipy 
from config import weather_api_key
import pandas as pd
import requests
import time
from datetime import datetime

# %%
# Create a new set of 2,000 random latitudes and longitude
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 724

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3070c0172a131b68ab37ad740fc0d11f

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_weather = city_weather["weather"][0]['description'] 
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "City Description": city_current_weather})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | batagay
# Processing Record 3 of Set 1 | portlethen
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | guerrero negro
# Processing Record 6 of Set 1 | alyangula
# Processing Record 7 of Set 1 | sibolga
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | norilsk
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | aquiraz
# Processing Record 12 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | victoria
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | kodiak
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | matay
# Processing Record 20 of Set 1 | vadlapudi
# Processing Record 21 of Set 1 | esperance
# Processing Record 22 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 1 | iqaluit
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | yar-sale
# Processing Record 28 of Set 1 | barstow
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | qurunbaliyah
# City not found. Skipping...
# Processing Record 36 of Set 1 | geraldton
# Processing Record 37 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 1 | puerto escondido
# Processing Record 39 of Set 1 | komsomolskiy
# Processing Record 40 of Set 1 | peleduy
# Processing Record 41 of Set 1 | busembatia
# Processing Record 42 of Set 1 | neiafu
# Processing Record 43 of Set 1 | burnie
# Processing Record 44 of Set 1 | bethel
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 1 | smithers
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | baruun-urt
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | lasa
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | cherskiy
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | urumqi
# Processing Record 7 of Set 2 | thunder bay
# Processing Record 8 of Set 2 | madoc
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | castro
# Processing Record 11 of Set 2 | pitimbu
# Processing Record 12 of Set 2 | san patricio
# Processing Record 13 of Set 2 | faanui
# Processing Record 14 of Set 2 | minsk
# Processing Record 15 of Set 2 | qaanaaq
# Processing Record 16 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 2 | kavieng
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | rio grande
# Processing Record 20 of Set 2 | araguaina
# Processing Record 21 of Set 2 | cabo san lucas
# Processing Record 22 of Set 2 | korem
# Processing Record 23 of Set 2 | qasigiannguit
# Processing Record 24 of Set 2 | wajima
# Processing Record 25 of Set 2 | tvoroyri
# Processing Record 26 of Set 2 | khani
# Processing Record 27 of Set 2 | kruisfontein
# Processing Record 28 of Set 2 | luderitz
# Processing Record 29 of Set 2 | kapoeta
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | tiksi
# Processing Record 32 of Set 2 | salinopolis
# Processing Record 33 of Set 2 | rabat
# Processing Record 34 of Set 2 | grindavik
# Processing Record 35 of Set 2 | honningsvag
# Processing Record 36 of Set 2 | saiki
# Processing Record 37 of Set 2 | tevriz
# Processing Record 38 of Set 2 | basoda
# Processing Record 39 of Set 2 | klaksvik
# Processing Record 40 of Set 2 | dicabisagan
# Processing Record 41 of Set 2 | vao
# Processing Record 42 of Set 2 | vestmanna
# Processing Record 43 of Set 2 | yarega
# Processing Record 44 of Set 2 | sept-iles
# Processing Record 45 of Set 2 | sitka
# Processing Record 46 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 47 of Set 2 | sibu
# Processing Record 48 of Set 2 | saskylakh
# Processing Record 49 of Set 2 | juneau
# Processing Record 50 of Set 2 | aklavik
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | dahuk
# Processing Record 3 of Set 3 | nioro
# Processing Record 4 of Set 3 | amzya
# Processing Record 5 of Set 3 | waddan
# Processing Record 6 of Set 3 | cockburn town
# Processing Record 7 of Set 3 | lagoa
# Processing Record 8 of Set 3 | trojes
# Processing Record 9 of Set 3 | acapulco
# Processing Record 10 of Set 3 | port alfred
# Processing Record 11 of Set 3 | yonibana
# Processing Record 12 of Set 3 | dikson
# Processing Record 13 of Set 3 | kupang
# Processing Record 14 of Set 3 | new baltimore
# Processing Record 15 of Set 3 | christchurch
# Processing Record 16 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 17 of Set 3 | paragould
# Processing Record 18 of Set 3 | souillac
# Processing Record 19 of Set 3 | port elizabeth
# Processing Record 20 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 3 | prince rupert
# Processing Record 22 of Set 3 | mataura
# Processing Record 23 of Set 3 | silopi
# Processing Record 24 of Set 3 | okahandja
# Processing Record 25 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 3 | asau
# Processing Record 27 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 3 | mareeba
# Processing Record 29 of Set 3 | vardo
# Processing Record 30 of Set 3 | buala
# Processing Record 31 of Set 3 | pacific grove
# Processing Record 32 of Set 3 | paamiut
# Processing Record 33 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 3 | olinda
# Processing Record 35 of Set 3 | umm lajj
# Processing Record 36 of Set 3 | aloleng
# Processing Record 37 of Set 3 | castanos
# Processing Record 38 of Set 3 | egvekinot
# Processing Record 39 of Set 3 | varhaug
# Processing Record 40 of Set 3 | ulkan
# Processing Record 41 of Set 3 | ridgecrest
# Processing Record 42 of Set 3 | natchez
# Processing Record 43 of Set 3 | cidreira
# Processing Record 44 of Set 3 | tanabe
# Processing Record 45 of Set 3 | ilulissat
# Processing Record 46 of Set 3 | east london
# Processing Record 47 of Set 3 | toppenish
# Processing Record 48 of Set 3 | provideniya
# Processing Record 49 of Set 3 | salgueiro
# Processing Record 50 of Set 3 | nemuro
# Processing Record 1 of Set 4 | atar
# Processing Record 2 of Set 4 | saint george
# Processing Record 3 of Set 4 | viransehir
# Processing Record 4 of Set 4 | whitehorse
# Processing Record 5 of Set 4 | sisimiut
# Processing Record 6 of Set 4 | black river
# Processing Record 7 of Set 4 | puerto leguizamo
# Processing Record 8 of Set 4 | bereznik
# Processing Record 9 of Set 4 | pisco
# Processing Record 10 of Set 4 | lodwar
# Processing Record 11 of Set 4 | kavaratti
# Processing Record 12 of Set 4 | coihaique
# Processing Record 13 of Set 4 | namibe
# Processing Record 14 of Set 4 | miri
# Processing Record 15 of Set 4 | severo-yeniseyskiy
# Processing Record 16 of Set 4 | chokurdakh
# Processing Record 17 of Set 4 | cornwall
# Processing Record 18 of Set 4 | naumburg
# Processing Record 19 of Set 4 | torbay
# Processing Record 20 of Set 4 | khatanga
# Processing Record 21 of Set 4 | mont-de-marsan
# Processing Record 22 of Set 4 | los llanos de aridane
# Processing Record 23 of Set 4 | biak
# Processing Record 24 of Set 4 | narsaq
# Processing Record 25 of Set 4 | uyo
# Processing Record 26 of Set 4 | yabrud
# Processing Record 27 of Set 4 | ritchie
# Processing Record 28 of Set 4 | yellowknife
# Processing Record 29 of Set 4 | sinazongwe
# Processing Record 30 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 31 of Set 4 | bengkulu
# Processing Record 32 of Set 4 | treinta y tres
# Processing Record 33 of Set 4 | tres de maio
# Processing Record 34 of Set 4 | sao filipe
# Processing Record 35 of Set 4 | tbilisi
# Processing Record 36 of Set 4 | longyearbyen
# Processing Record 37 of Set 4 | bitburg
# Processing Record 38 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 39 of Set 4 | charters towers
# Processing Record 40 of Set 4 | tahe
# Processing Record 41 of Set 4 | ostrovnoy
# Processing Record 42 of Set 4 | nanortalik
# Processing Record 43 of Set 4 | fortuna
# Processing Record 44 of Set 4 | shangrao
# Processing Record 45 of Set 4 | jasdan
# Processing Record 46 of Set 4 | kahului
# Processing Record 47 of Set 4 | tulsipur
# Processing Record 48 of Set 4 | hami
# Processing Record 49 of Set 4 | labuhan
# Processing Record 50 of Set 4 | leh
# Processing Record 1 of Set 5 | istanbul
# Processing Record 2 of Set 5 | honiara
# Processing Record 3 of Set 5 | tayturka
# Processing Record 4 of Set 5 | kiruna
# Processing Record 5 of Set 5 | hilo
# Processing Record 6 of Set 5 | filadelfia
# Processing Record 7 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 5 | san quintin
# Processing Record 9 of Set 5 | sabang
# Processing Record 10 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 5 | norman wells
# Processing Record 12 of Set 5 | nikolskoye
# Processing Record 13 of Set 5 | manado
# Processing Record 14 of Set 5 | inirida
# Processing Record 15 of Set 5 | richards bay
# Processing Record 16 of Set 5 | sironko
# Processing Record 17 of Set 5 | hasaki
# Processing Record 18 of Set 5 | lamu
# Processing Record 19 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 5 | san jose
# Processing Record 21 of Set 5 | henties bay
# Processing Record 22 of Set 5 | korba
# Processing Record 23 of Set 5 | tomatlan
# Processing Record 24 of Set 5 | quatre cocos
# Processing Record 25 of Set 5 | tilichiki
# Processing Record 26 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 5 | kieta
# Processing Record 28 of Set 5 | katsuura
# Processing Record 29 of Set 5 | portland
# Processing Record 30 of Set 5 | meghraj
# Processing Record 31 of Set 5 | new norfolk
# Processing Record 32 of Set 5 | harrison
# Processing Record 33 of Set 5 | chuy
# Processing Record 34 of Set 5 | brazzaville
# Processing Record 35 of Set 5 | karmana
# City not found. Skipping...
# Processing Record 36 of Set 5 | aasiaat
# Processing Record 37 of Set 5 | ranong
# Processing Record 38 of Set 5 | lorengau
# Processing Record 39 of Set 5 | mount gambier
# Processing Record 40 of Set 5 | samarai
# Processing Record 41 of Set 5 | senno
# Processing Record 42 of Set 5 | kikwit
# Processing Record 43 of Set 5 | okhotsk
# Processing Record 44 of Set 5 | lompoc
# Processing Record 45 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 5 | kaitangata
# Processing Record 47 of Set 5 | santa luzia
# Processing Record 48 of Set 5 | mpika
# Processing Record 49 of Set 5 | kawalu
# Processing Record 50 of Set 5 | svetlyy
# Processing Record 1 of Set 6 | vila velha
# Processing Record 2 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 3 of Set 6 | odweyne
# Processing Record 4 of Set 6 | talcahuano
# Processing Record 5 of Set 6 | hambantota
# Processing Record 6 of Set 6 | tasiilaq
# Processing Record 7 of Set 6 | severo-kurilsk
# Processing Record 8 of Set 6 | mangrol
# Processing Record 9 of Set 6 | bluff
# Processing Record 10 of Set 6 | ikalamavony
# Processing Record 11 of Set 6 | saint-augustin
# Processing Record 12 of Set 6 | bambous virieux
# Processing Record 13 of Set 6 | opuwo
# Processing Record 14 of Set 6 | izumo
# Processing Record 15 of Set 6 | comodoro rivadavia
# Processing Record 16 of Set 6 | coquimbo
# Processing Record 17 of Set 6 | salamanca
# Processing Record 18 of Set 6 | semey
# Processing Record 19 of Set 6 | texarkana
# Processing Record 20 of Set 6 | pevek
# Processing Record 21 of Set 6 | rensvik
# Processing Record 22 of Set 6 | kalashnikovo
# Processing Record 23 of Set 6 | brandon
# Processing Record 24 of Set 6 | nago
# Processing Record 25 of Set 6 | kununurra
# Processing Record 26 of Set 6 | skegness
# Processing Record 27 of Set 6 | baykit
# Processing Record 28 of Set 6 | dudinka
# Processing Record 29 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 6 | bulgan
# Processing Record 31 of Set 6 | brive-la-gaillarde
# Processing Record 32 of Set 6 | russkiy kameshkir
# Processing Record 33 of Set 6 | codrington
# Processing Record 34 of Set 6 | coron
# Processing Record 35 of Set 6 | camacha
# Processing Record 36 of Set 6 | copiapo
# Processing Record 37 of Set 6 | lichinga
# Processing Record 38 of Set 6 | porto velho
# Processing Record 39 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 6 | caravelas
# Processing Record 41 of Set 6 | ihosy
# Processing Record 42 of Set 6 | kuryk
# Processing Record 43 of Set 6 | tambo
# Processing Record 44 of Set 6 | lynn haven
# Processing Record 45 of Set 6 | pangnirtung
# Processing Record 46 of Set 6 | srivardhan
# Processing Record 47 of Set 6 | corn island
# Processing Record 48 of Set 6 | valparaiso
# Processing Record 49 of Set 6 | bonnyville
# Processing Record 50 of Set 6 | alofi
# Processing Record 1 of Set 7 | vitimskiy
# City not found. Skipping...
# Processing Record 2 of Set 7 | mosquera
# Processing Record 3 of Set 7 | rio gallegos
# Processing Record 4 of Set 7 | airai
# Processing Record 5 of Set 7 | kizema
# Processing Record 6 of Set 7 | mbini
# Processing Record 7 of Set 7 | ust-kan
# Processing Record 8 of Set 7 | ginda
# Processing Record 9 of Set 7 | masterton
# Processing Record 10 of Set 7 | lixourion
# Processing Record 11 of Set 7 | hamilton
# Processing Record 12 of Set 7 | piacabucu
# Processing Record 13 of Set 7 | veles
# Processing Record 14 of Set 7 | nara
# Processing Record 15 of Set 7 | fare
# Processing Record 16 of Set 7 | clarksdale
# Processing Record 17 of Set 7 | huarmey
# Processing Record 18 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 19 of Set 7 | hithadhoo
# Processing Record 20 of Set 7 | pahrump
# Processing Record 21 of Set 7 | mitsamiouli
# Processing Record 22 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 7 | watsa
# Processing Record 24 of Set 7 | miranda
# Processing Record 25 of Set 7 | chalchihuites
# Processing Record 26 of Set 7 | san pedro
# Processing Record 27 of Set 7 | yaan
# Processing Record 28 of Set 7 | dubbo
# Processing Record 29 of Set 7 | ibanda
# Processing Record 30 of Set 7 | hualmay
# Processing Record 31 of Set 7 | voznesenye
# Processing Record 32 of Set 7 | kaeo
# Processing Record 33 of Set 7 | mayo
# Processing Record 34 of Set 7 | birao
# Processing Record 35 of Set 7 | fuerte olimpo
# Processing Record 36 of Set 7 | nerchinsk
# Processing Record 37 of Set 7 | arraial do cabo
# Processing Record 38 of Set 7 | nhulunbuy
# Processing Record 39 of Set 7 | fort frances
# Processing Record 40 of Set 7 | mahon
# Processing Record 41 of Set 7 | talnakh
# Processing Record 42 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 7 | teguldet
# Processing Record 44 of Set 7 | abu dhabi
# Processing Record 45 of Set 7 | waipawa
# Processing Record 46 of Set 7 | sokoni
# Processing Record 47 of Set 7 | mirnyy
# Processing Record 48 of Set 7 | salalah
# Processing Record 49 of Set 7 | dongsheng
# Processing Record 50 of Set 7 | berlin
# Processing Record 1 of Set 8 | ornskoldsvik
# Processing Record 2 of Set 8 | phuket
# Processing Record 3 of Set 8 | stephenville crossing
# Processing Record 4 of Set 8 | cayenne
# Processing Record 5 of Set 8 | poum
# Processing Record 6 of Set 8 | porto murtinho
# Processing Record 7 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 8 | ust-nera
# Processing Record 9 of Set 8 | algeciras
# Processing Record 10 of Set 8 | port blair
# Processing Record 11 of Set 8 | chinhoyi
# Processing Record 12 of Set 8 | lebu
# Processing Record 13 of Set 8 | korla
# Processing Record 14 of Set 8 | auki
# Processing Record 15 of Set 8 | teya
# Processing Record 16 of Set 8 | san policarpo
# Processing Record 17 of Set 8 | oistins
# Processing Record 18 of Set 8 | faya
# Processing Record 19 of Set 8 | itarema
# Processing Record 20 of Set 8 | liverpool
# Processing Record 21 of Set 8 | cap malheureux
# Processing Record 22 of Set 8 | gat
# Processing Record 23 of Set 8 | sinnamary
# Processing Record 24 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 8 | cochrane
# Processing Record 26 of Set 8 | kirensk
# Processing Record 27 of Set 8 | callaway
# Processing Record 28 of Set 8 | cairns
# Processing Record 29 of Set 8 | luba
# Processing Record 30 of Set 8 | petauke
# Processing Record 31 of Set 8 | fort smith
# Processing Record 32 of Set 8 | havelock
# Processing Record 33 of Set 8 | maarianhamina
# Processing Record 34 of Set 8 | katherine
# Processing Record 35 of Set 8 | sakaraha
# Processing Record 36 of Set 8 | avera
# Processing Record 37 of Set 8 | marathopolis
# City not found. Skipping...
# Processing Record 38 of Set 8 | manokwari
# Processing Record 39 of Set 8 | bouca
# Processing Record 40 of Set 8 | erzin
# Processing Record 41 of Set 8 | marv dasht
# City not found. Skipping...
# Processing Record 42 of Set 8 | moose factory
# Processing Record 43 of Set 8 | nueva concepcion
# Processing Record 44 of Set 8 | general pico
# Processing Record 45 of Set 8 | tinskoy
# Processing Record 46 of Set 8 | termiz
# Processing Record 47 of Set 8 | gabu
# Processing Record 48 of Set 8 | deder
# Processing Record 49 of Set 8 | port lincoln
# Processing Record 50 of Set 8 | mayskiy
# Processing Record 1 of Set 9 | tuatapere
# Processing Record 2 of Set 9 | sao miguel do araguaia
# Processing Record 3 of Set 9 | cabangahan
# Processing Record 4 of Set 9 | santa isabel
# Processing Record 5 of Set 9 | gornyatskiy
# Processing Record 6 of Set 9 | bubaque
# Processing Record 7 of Set 9 | gigmoto
# Processing Record 8 of Set 9 | asfi
# Processing Record 9 of Set 9 | ulcinj
# Processing Record 10 of Set 9 | rudbar
# Processing Record 11 of Set 9 | half moon bay
# Processing Record 12 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 9 | nogliki
# Processing Record 14 of Set 9 | dekoa
# City not found. Skipping...
# Processing Record 15 of Set 9 | te anau
# Processing Record 16 of Set 9 | santa eulalia
# Processing Record 17 of Set 9 | macheng
# Processing Record 18 of Set 9 | goundam
# Processing Record 19 of Set 9 | bismarck
# Processing Record 20 of Set 9 | warmbad
# Processing Record 21 of Set 9 | mercedes
# Processing Record 22 of Set 9 | hartford
# Processing Record 23 of Set 9 | shitanjing
# Processing Record 24 of Set 9 | roma
# Processing Record 25 of Set 9 | santa cruz
# Processing Record 26 of Set 9 | college
# Processing Record 27 of Set 9 | puerto narino
# Processing Record 28 of Set 9 | margate
# Processing Record 29 of Set 9 | kalomo
# City not found. Skipping...
# Processing Record 30 of Set 9 | flinders
# Processing Record 31 of Set 9 | solnechnyy
# Processing Record 32 of Set 9 | puerto maldonado
# Processing Record 33 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 34 of Set 9 | shingu
# Processing Record 35 of Set 9 | ha giang
# Processing Record 36 of Set 9 | hofn
# Processing Record 37 of Set 9 | port hardy
# Processing Record 38 of Set 9 | miranda de ebro
# Processing Record 39 of Set 9 | grand-lahou
# Processing Record 40 of Set 9 | taicheng
# Processing Record 41 of Set 9 | husavik
# Processing Record 42 of Set 9 | moindou
# Processing Record 43 of Set 9 | krasnoarmeysk
# Processing Record 44 of Set 9 | tautira
# Processing Record 45 of Set 9 | bibiani
# Processing Record 46 of Set 9 | saint-joseph
# Processing Record 47 of Set 9 | puerto madero
# Processing Record 48 of Set 9 | finschhafen
# Processing Record 49 of Set 9 | port keats
# Processing Record 50 of Set 9 | vysokogornyy
# Processing Record 1 of Set 10 | corinto
# Processing Record 2 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 10 | verkhnevilyuysk
# Processing Record 4 of Set 10 | brae
# Processing Record 5 of Set 10 | walvis bay
# Processing Record 6 of Set 10 | laguna
# Processing Record 7 of Set 10 | plettenberg bay
# Processing Record 8 of Set 10 | prainha
# Processing Record 9 of Set 10 | bonavista
# Processing Record 10 of Set 10 | sorong
# Processing Record 11 of Set 10 | poli
# Processing Record 12 of Set 10 | mount isa
# Processing Record 13 of Set 10 | wukari
# Processing Record 14 of Set 10 | ixtapa
# Processing Record 15 of Set 10 | rantepao
# Processing Record 16 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 10 | itaituba
# Processing Record 18 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 10 | lazaro cardenas
# Processing Record 20 of Set 10 | hovd
# Processing Record 21 of Set 10 | santa helena
# Processing Record 22 of Set 10 | zhigansk
# Processing Record 23 of Set 10 | tura
# Processing Record 24 of Set 10 | tabou
# Processing Record 25 of Set 10 | chapais
# Processing Record 26 of Set 10 | nenjiang
# Processing Record 27 of Set 10 | ponta do sol
# Processing Record 28 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 10 | navirai
# Processing Record 30 of Set 10 | phalaborwa
# Processing Record 31 of Set 10 | altay
# Processing Record 32 of Set 10 | north bend
# Processing Record 33 of Set 10 | novoorsk
# Processing Record 34 of Set 10 | niteroi
# Processing Record 35 of Set 10 | biabou
# Processing Record 36 of Set 10 | svetlaya
# Processing Record 37 of Set 10 | abha
# Processing Record 38 of Set 10 | broome
# Processing Record 39 of Set 10 | tiznit
# Processing Record 40 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 10 | shimoda
# Processing Record 42 of Set 10 | lubango
# Processing Record 43 of Set 10 | belmonte
# Processing Record 44 of Set 10 | goure
# Processing Record 45 of Set 10 | caraquet
# Processing Record 46 of Set 10 | boguchany
# Processing Record 47 of Set 10 | dongying
# Processing Record 48 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 49 of Set 10 | andenes
# Processing Record 50 of Set 10 | upernavik
# Processing Record 1 of Set 11 | kasongo
# Processing Record 2 of Set 11 | makaha
# Processing Record 3 of Set 11 | price
# Processing Record 4 of Set 11 | lakes entrance
# Processing Record 5 of Set 11 | grand gaube
# Processing Record 6 of Set 11 | hashtrud
# Processing Record 7 of Set 11 | praia
# Processing Record 8 of Set 11 | abu samrah
# Processing Record 9 of Set 11 | nurota
# Processing Record 10 of Set 11 | vestmannaeyjar
# Processing Record 11 of Set 11 | tazovskiy
# Processing Record 12 of Set 11 | kolpashevo
# Processing Record 13 of Set 11 | tamandare
# Processing Record 14 of Set 11 | kainantu
# Processing Record 15 of Set 11 | vila franca do campo
# Processing Record 16 of Set 11 | cagsiay
# Processing Record 17 of Set 11 | meulaboh
# Processing Record 18 of Set 11 | mezen
# Processing Record 19 of Set 11 | date
# Processing Record 20 of Set 11 | valdez
# Processing Record 21 of Set 11 | rossosh
# Processing Record 22 of Set 11 | rawson
# Processing Record 23 of Set 11 | achutupo
# Processing Record 24 of Set 11 | wajid
# Processing Record 25 of Set 11 | saldanha
# Processing Record 26 of Set 11 | kargil
# Processing Record 27 of Set 11 | sosnovo-ozerskoye
# Processing Record 28 of Set 11 | oranjemund
# Processing Record 29 of Set 11 | kabinda
# Processing Record 30 of Set 11 | isangel
# Processing Record 31 of Set 11 | ambanja
# Processing Record 32 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 11 | tual
# Processing Record 35 of Set 11 | makakilo city
# Processing Record 36 of Set 11 | falun
# Processing Record 37 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 11 | pingliang
# Processing Record 39 of Set 11 | pimentel
# Processing Record 40 of Set 11 | muros
# Processing Record 41 of Set 11 | tikrit
# Processing Record 42 of Set 11 | ghanzi
# Processing Record 43 of Set 11 | sorland
# Processing Record 44 of Set 11 | gushikawa
# Processing Record 45 of Set 11 | kulhudhuffushi
# Processing Record 46 of Set 11 | requena
# Processing Record 47 of Set 11 | priargunsk
# Processing Record 48 of Set 11 | kinsale
# Processing Record 49 of Set 11 | yulara
# Processing Record 50 of Set 11 | arlit
# Processing Record 1 of Set 12 | mocuba
# Processing Record 2 of Set 12 | omurtag
# Processing Record 3 of Set 12 | conakry
# Processing Record 4 of Set 12 | sal rei
# Processing Record 5 of Set 12 | emba
# Processing Record 6 of Set 12 | amahai
# Processing Record 7 of Set 12 | axim
# Processing Record 8 of Set 12 | saint anthony
# Processing Record 9 of Set 12 | ust-kuyga
# Processing Record 10 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 12 | bathsheba
# Processing Record 12 of Set 12 | iskateley
# Processing Record 13 of Set 12 | wanning
# Processing Record 14 of Set 12 | mahibadhoo
# Processing Record 15 of Set 12 | monrovia
# Processing Record 16 of Set 12 | caruaru
# Processing Record 17 of Set 12 | sungairaya
# Processing Record 18 of Set 12 | san rafael del sur
# Processing Record 19 of Set 12 | ratnagiri
# Processing Record 20 of Set 12 | west bay
# Processing Record 21 of Set 12 | ancud
# Processing Record 22 of Set 12 | iisalmi
# Processing Record 23 of Set 12 | najran
# Processing Record 24 of Set 12 | tigre
# Processing Record 25 of Set 12 | contamana
# Processing Record 26 of Set 12 | erdenet
# Processing Record 27 of Set 12 | beringovskiy
# Processing Record 28 of Set 12 | great bend
# Processing Record 29 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 30 of Set 12 | humberto de campos
# Processing Record 31 of Set 12 | fengzhen
# Processing Record 32 of Set 12 | sioux lookout
# Processing Record 33 of Set 12 | sidi ali
# Processing Record 34 of Set 12 | ken caryl
# Processing Record 35 of Set 12 | magrath
# Processing Record 36 of Set 12 | sovetskiy
# Processing Record 37 of Set 12 | gondanglegi
# Processing Record 38 of Set 12 | kijang
# Processing Record 39 of Set 12 | chernyshevskiy
# Processing Record 40 of Set 12 | azanka
# Processing Record 41 of Set 12 | antalaha
# Processing Record 42 of Set 12 | nueva londres
# Processing Record 43 of Set 12 | banda aceh
# Processing Record 44 of Set 12 | the valley
# Processing Record 45 of Set 12 | esil
# Processing Record 46 of Set 12 | sarangani
# Processing Record 47 of Set 12 | pasni
# Processing Record 48 of Set 12 | san vicente de canete
# Processing Record 49 of Set 12 | sukhoverkovo
# City not found. Skipping...
# Processing Record 50 of Set 12 | antalya
# Processing Record 1 of Set 13 | capim grosso
# Processing Record 2 of Set 13 | tignere
# Processing Record 3 of Set 13 | dalby
# Processing Record 4 of Set 13 | kardamas
# Processing Record 5 of Set 13 | port saint john
# Processing Record 6 of Set 13 | usinsk
# Processing Record 7 of Set 13 | santa marta
# Processing Record 8 of Set 13 | karratha
# Processing Record 9 of Set 13 | bisho
# Processing Record 10 of Set 13 | lewiston
# Processing Record 11 of Set 13 | havre-saint-pierre
# Processing Record 12 of Set 13 | ginir
# Processing Record 13 of Set 13 | xihe
# Processing Record 14 of Set 13 | nantucket
# Processing Record 15 of Set 13 | fort nelson
# Processing Record 16 of Set 13 | cuamba
# Processing Record 17 of Set 13 | vega de alatorre
# Processing Record 18 of Set 13 | kyzyl-suu
# Processing Record 19 of Set 13 | dhidhdhoo
# Processing Record 20 of Set 13 | hernani
# Processing Record 21 of Set 13 | mawlaik
# Processing Record 22 of Set 13 | hanna
# Processing Record 23 of Set 13 | ahipara
# Processing Record 24 of Set 13 | ucluelet
# Processing Record 25 of Set 13 | george
# Processing Record 26 of Set 13 | petaluma
# Processing Record 27 of Set 13 | tondano
# Processing Record 28 of Set 13 | porto novo
# Processing Record 29 of Set 13 | wlingi
# Processing Record 30 of Set 13 | mlalo
# Processing Record 31 of Set 13 | abatskoye
# Processing Record 32 of Set 13 | road town
# Processing Record 33 of Set 13 | harper
# Processing Record 34 of Set 13 | xapuri
# Processing Record 35 of Set 13 | sibut
# Processing Record 36 of Set 13 | arman
# Processing Record 37 of Set 13 | talara
# Processing Record 38 of Set 13 | pitkyaranta
# Processing Record 39 of Set 13 | chiredzi
# Processing Record 40 of Set 13 | nchelenge
# Processing Record 41 of Set 13 | warwick
# Processing Record 42 of Set 13 | yumen
# Processing Record 43 of Set 13 | griffith
# Processing Record 44 of Set 13 | skibotn
# Processing Record 45 of Set 13 | roald
# Processing Record 46 of Set 13 | sawtell
# Processing Record 47 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 48 of Set 13 | viedma
# Processing Record 49 of Set 13 | chegem
# Processing Record 50 of Set 13 | pavino
# Processing Record 1 of Set 14 | port-cartier
# Processing Record 2 of Set 14 | massakory
# Processing Record 3 of Set 14 | lieto
# Processing Record 4 of Set 14 | batsfjord
# Processing Record 5 of Set 14 | bilibino
# Processing Record 6 of Set 14 | jurado
# Processing Record 7 of Set 14 | ambilobe
# Processing Record 8 of Set 14 | cururupu
# Processing Record 9 of Set 14 | beloha
# Processing Record 10 of Set 14 | altamira
# Processing Record 11 of Set 14 | alice springs
# Processing Record 12 of Set 14 | gusau
# Processing Record 13 of Set 14 | novoilinsk
# Processing Record 14 of Set 14 | nyurba
# Processing Record 15 of Set 14 | necochea
# Processing Record 16 of Set 14 | bagala
# Processing Record 17 of Set 14 | lumby
# Processing Record 18 of Set 14 | urengoy
# Processing Record 19 of Set 14 | bukama
# Processing Record 20 of Set 14 | constitucion
# Processing Record 21 of Set 14 | gorom-gorom
# Processing Record 22 of Set 14 | udachnyy
# Processing Record 23 of Set 14 | moorhead
# Processing Record 24 of Set 14 | mitu
# Processing Record 25 of Set 14 | coahuayana
# Processing Record 26 of Set 14 | beroroha
# Processing Record 27 of Set 14 | srednekolymsk
# Processing Record 28 of Set 14 | san cristobal
# Processing Record 29 of Set 14 | tateyama
# Processing Record 30 of Set 14 | lucapa
# Processing Record 31 of Set 14 | bud
# Processing Record 32 of Set 14 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 33 of Set 14 | sirhind
# Processing Record 34 of Set 14 | qaqortoq
# Processing Record 35 of Set 14 | caldwell
# Processing Record 36 of Set 14 | daru
# Processing Record 37 of Set 14 | hede
# Processing Record 38 of Set 14 | jibuti
# Processing Record 39 of Set 14 | belle fourche
# Processing Record 40 of Set 14 | fuxin
# Processing Record 41 of Set 14 | chicama
# Processing Record 42 of Set 14 | safranbolu
# Processing Record 43 of Set 14 | hobyo
# Processing Record 44 of Set 14 | ausa
# Processing Record 45 of Set 14 | salekhard
# Processing Record 46 of Set 14 | anzio
# Processing Record 47 of Set 14 | braniewo
# Processing Record 48 of Set 14 | savannah bight
# Processing Record 49 of Set 14 | vostok
# Processing Record 50 of Set 14 | vreed en hoop
# City not found. Skipping...
# Processing Record 1 of Set 15 | morgan city
# Processing Record 2 of Set 15 | rio verde de mato grosso
# Processing Record 3 of Set 15 | gejiu
# Processing Record 4 of Set 15 | dobric
# Processing Record 5 of Set 15 | picayune
# Processing Record 6 of Set 15 | ciudad bolivar
# Processing Record 7 of Set 15 | vikersund
# Processing Record 8 of Set 15 | postojna
# Processing Record 9 of Set 15 | kaya
# Processing Record 10 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 11 of Set 15 | vadso
# Processing Record 12 of Set 15 | montepuez
# Processing Record 13 of Set 15 | hervey bay
# Processing Record 14 of Set 15 | shelburne
# Processing Record 15 of Set 15 | rockport
# Processing Record 16 of Set 15 | pavilosta
# Processing Record 17 of Set 15 | kokuy
# Processing Record 18 of Set 15 | monchegorsk
# Processing Record 19 of Set 15 | cazaje
# City not found. Skipping...
# Processing Record 20 of Set 15 | stornoway
# Processing Record 21 of Set 15 | guatire
# Processing Record 22 of Set 15 | ekhabi
# Processing Record 23 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 24 of Set 15 | carbonear
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Tuktoyaktuk      CA  69.4541 -133.0374     41.00        87          75
# 1         Batagay      RU  67.6333  134.6333     34.65        79         100
# 2      Portlethen      GB  57.0547   -2.1307     47.97        84          75
# 3         Rikitea      PF -23.1203 -134.9692     72.55        68           0
# 4  Guerrero Negro      MX  27.9769 -114.0611     74.93        62           0
#
#    Wind Speed City Description
# 0        8.05    broken clouds
# 1        6.64  overcast clouds
# 2       14.97    broken clouds
# 3       13.11        clear sky
# 4       18.88        clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
